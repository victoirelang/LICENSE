# %%
from data import database
filter_Isopropyl(database)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from data import database
#       2 filter_Isopropyl(database)
#
# ModuleNotFoundError: No module named 'data'

# %%
###We forgot to import our database!

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/victoirelang/Project/main/data/database.csv"
database= pd.read_csv(url, sep=';')
database
# Out:
#               Cream                               Molecule      Formula  \
# 0    La Roche-Posay                                  Water          H2O
# 1    La Roche-Posay                               Glycerin       C3H8O3
# 2    La Roche-Posay                      Cyclohexasiloxane  C12H36O6Si6
# 3    La Roche-Posay             Hydrogenated Polyisobutene      (C4H8)n
# 4    La Roche-Posay  Ammonium Polyacryloyldimethyl Taurate          NaN
# ..              ...                                    ...          ...
# 376        La Neige                           Zinc Sulfate        ZnSO4
# 377        La Neige                  PEG-5 Rapeseed Sterol          NaN
# 378        La Neige                    Copper Tripeptide-1          NaN
# 379        La Neige                       Phytosphingosine    C18H39NO3
# 380        La Neige                     Ascorbyl Glucoside    C12H18O11
#
#       CAS Number                                             SMILES  \
# ...

# %%
filter_Isopropyl(database)
# Out:
#         Cream             Molecule   Formula CAS Number  \
# 100  La Rosée  Isopropyl Palmitate  C19H38O2   142-91-6
#
#                         SMILES              Function     Origin  \
# 100  CCCCCCCCCCCCCCC(=O)OC(C)C  Emollient, thickener  Synthetic
#
#     Physical Properties Chemical Properties Dermatological Properties  ...  \
# 100     Colorless, oily        Non-reactive   Moisturizing, softening  ...
#
#     Pregnancy Risk Suitable for Children (0-3 years)  \
# 100             No                               Yes
#
#     Suitable for Youth (3-16 years) Chirality Esther Group Alcohol Group  \
# 100                             Yes        No          Yes           Yes
#
#     Benzyl Group Silicate Groups Alkyl Parahydroxybenzoate Group  \
# 100           No              No                              No
#
#     Availability Type
# 100  Over-the-counter
#
# [1 rows x 22 columns]

# %%
new_database_no_Isopropyl(database)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 new_database_no_Isopropyl(database)
#
# NameError: name 'new_database_no_Isopropyl' is not defined

# %%
from functions import new_database_no_Isopropyl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from functions import new_database_no_Isopropyl
#
# ModuleNotFoundError: No module named 'functions'
