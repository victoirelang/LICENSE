# %%
#Now that we have found our best cream and that we have ranked the creams in order from best to worst creams for pregnant women, we would like to visualize the bad molecules of our creams

# %%
#Instead of running a function which filters out bad molecules, it would be interesting to show each molecule in a cream and, using RDKit, make the bad groups pop out so that simply looking at a creme's molecules, we can indentify which is bad.

# %%
#Let's do this using bad molecules we used to filter creams out. We will color the molecules differently in order to tell them a part.

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/victoirelang/Project/main/data/database.csv"
database= pd.read_csv(url, sep=';')
database
# Out:
#               Cream                               Molecule      Formula  \
# 0    La Roche-Posay                                  Water          H2O
# 1    La Roche-Posay                               Glycerin       C3H8O3
# 2    La Roche-Posay                      Cyclohexasiloxane  C12H36O6Si6
# 3    La Roche-Posay             Hydrogenated Polyisobutene      (C4H8)n
# 4    La Roche-Posay  Ammonium Polyacryloyldimethyl Taurate          NaN
# ..              ...                                    ...          ...
# 376        La Neige                           Zinc Sulfate        ZnSO4
# 377        La Neige                  PEG-5 Rapeseed Sterol          NaN
# 378        La Neige                    Copper Tripeptide-1          NaN
# 379        La Neige                       Phytosphingosine    C18H39NO3
# 380        La Neige                     Ascorbyl Glucoside    C12H18O11
#
#       CAS Number                                             Smiles  \
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from IPython.display import display

# %%
import sys
sys.path.append('../')

# %%
from functions.visualizing import visualize_molecules_for_cream

# %%
visualize_molecules_for_cream(database,"Nivea")
# Out:
# Total molécules pour la crème Nivea: 21
# Match trouvé pour Isopropyl dans la molécule C(C(CO)O)O
# Match trouvé pour Isopropyl dans la molécule CCCCCCCCCCCCCCCCCC(=O)OCCC(CO)O
# Match trouvé pour Isopropyl dans la molécule CC(C)C1C(C(C(C(O1)COC(=O)C(C)CCCC(C)C)C)O)(C)C
# Match trouvé pour NaOH dans la molécule [Na+].[OH-]
# Match trouvé pour Benzyl Alcohol dans la molécule OCC1=CC=CC=C1O
# Match trouvé pour Linalool dans la molécule CC(=C)CCC1=CC=C(C=C1)O
# Match trouvé pour Citronellol dans la molécule CC(C)CCC(C)CO
# Match trouvé pour Benzyl Alcohol dans la molécule c1ccccc1CO
# Match trouvé pour Limonene dans la molécule CC1=CC[C@H](C=C1)C(C)C
# Match trouvé pour Benzyl Alcohol dans la molécule COC1=CC=CC=C1C(=O)OCC2=CC=CC=C2
# Match trouvé pour Benzyl Salicylate dans la molécule COC1=CC=CC=C1C(=O)OCC2=CC=CC=C2
