# %%
From the script selectingbest, we know which cream is the best. However, we would like to rank our creams.
In order to do so, we decided to select the criteria of risks related to pregnancy.

# %%
import pandas as pd
url="https://raw.githubusercontent.com/victoirelang/Project/main/data/database.csv"
database= pd.read_csv(url, sep=';')
database
# Out:
#               Cream                               Molecule      Formula  \
# 0    La Roche-Posay                                  Water          H2O
# 1    La Roche-Posay                               Glycerin       C3H8O3
# 2    La Roche-Posay                      Cyclohexasiloxane  C12H36O6Si6
# 3    La Roche-Posay             Hydrogenated Polyisobutene      (C4H8)n
# 4    La Roche-Posay  Ammonium Polyacryloyldimethyl Taurate          NaN
# ..              ...                                    ...          ...
# 377        La Neige                           Zinc Sulfate        ZnSO4
# 378        La Neige                  PEG-5 Rapeseed Sterol          NaN
# 379        La Neige                    Copper Tripeptide-1          NaN
# 380        La Neige                       Phytosphingosine    C18H39NO3
# 381        La Neige                     Ascorbyl Glucoside    C12H18O11
#
#       CAS Number                                             SMILES  \
# ...

# %%
import sys
sys.path.append('../')
###like for the selectingbest script, we have to import from the functions folder

# %%
from functions.ranking import filter_pregnancy_risk

# %%
filter_pregnancy_risk(database)
# Out:
# Data base with molecules dangerous for pregnant women
#               Cream                                      Molecule  \
# 6    La Roche-Posay                                  Stearic Acid
# 7                No                                            No
# 19            Nivea                           Paraffinum Liquidum
# 22            Nivea                                Alcohol Denat.
# 40            Nivea                                      Linalool
# 41            Nivea                                   Citronellol
# 43            Nivea                                Benzyl Alcohol
# 44            Nivea                                      Limonene
# 45            Nivea                             Benzyl Salicylate
# 56             Nuxe                     Glyceryl Stearate Citrate
# 63             Nuxe                       Polyglyceryl-3 Stearate
# 81             Nuxe                             Capryloyl Glycine
# ...
