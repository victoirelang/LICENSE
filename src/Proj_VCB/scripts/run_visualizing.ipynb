# %%
#Now that we have found our best cream and that we have ranked the creams in order from best to worst creams for pregnant women, 
#we would like to visualize the bad molecules of our creams

# %%
#instead of running a function which filters out bad molecules, it would be interesting to show each molecule in a cream
#and, using RDKit, make the bad groups pop out so that when we know a cream is bad, simply looking at it's molecules, we can
#indentify which is bad.

# %%
#Let's do this using bad molecules we used to filter creams out. We will color the molecules differently in order to tell them a part.

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/victoirelang/Project/main/data/database.csv"
database= pd.read_csv(url, sep=';')
database
# Out:
#               Cream                               Molecule      Formula  \
# 0    La Roche-Posay                                  Water          H2O
# 1    La Roche-Posay                               Glycerin       C3H8O3
# 2    La Roche-Posay                      Cyclohexasiloxane  C12H36O6Si6
# 3    La Roche-Posay             Hydrogenated Polyisobutene      (C4H8)n
# 4    La Roche-Posay  Ammonium Polyacryloyldimethyl Taurate          NaN
# ..              ...                                    ...          ...
# 376        La Neige                           Zinc Sulfate        ZnSO4
# 377        La Neige                  PEG-5 Rapeseed Sterol          NaN
# 378        La Neige                    Copper Tripeptide-1          NaN
# 379        La Neige                       Phytosphingosine    C18H39NO3
# 380        La Neige                     Ascorbyl Glucoside    C12H18O11
#
#       CAS Number                                             SMILES  \
# 0      7732-18-5                                                  O
# 1        56-81-5                                         C(C(CO)O)O
# 2       540-97-6        O[Si](O[Si](O[Si](O[Si](O[Si](O1)C)C)C)C)C1
# 3     68527-49-1                                                NaN
# 4     62152-14-1                                                NaN
# ..           ...                                                ...
# 376    7733-02-0                           [Zn+2].[O-]S([O-])(=O)=O
# 377   68201-46-7                                                NaN
# 378   89030-95-5                                                NaN
# 379     554-62-1                          CCCCCCCCCCCCCCCC(N)(CO)CO
# 380  129499-78-1  C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)OC2=C([C@...
#
#                                      Function            Origin  \
# 0                       Solvent, moisturizer.           Natural
# 1                      Moisturizer, humectant           Natural
# 2                          Emollient, solvent         Synthetic
# 3                 Emollient, thickening agent         Synthetic
# 4           Viscosity controlling, stabilizer         Synthetic
# ..                                        ...               ...
# 376       Astringent, skin conditioning agent         Synthetic
# 377       Emulsifier, skin-conditioning agent         Synthetic
# 378       Skin conditioning, anti-aging agent  Biotechnological
# 379  Skin-identical ingredient, antimicrobial  Biotechnological
# 380       Antioxidant, skin brightening agent         Synthetic
#
#              Physical Properties        Chemical Properties  \
# 0              Colorless, liquid        pH 7, non-reactive.
# 1             Colorless, viscous          pH 7, hygroscopic
# 2                 Clear, viscous     Non-reactive, volatile
# 3                Colorless, oily  Non-reactive, hydrophobic
# 4                   White powder              pH-responsive
# ..                           ...                        ...
# 376     White powder or crystals               Non-reactive
# 377  Yellow to amber oily liquid            Mildly reactive
# 378                  Blue powder            Mildly reactive
# 379    White to off-white powder            Mildly reactive
# 380  White to pale yellow powder            Mildly reactive
#
#                              Dermatological Properties  ... Pregnancy Risk  \
# 0                                           Hydrating.  ...             No
# 1                                  Hydrating, soothing  ...             No
# 2                                 Softening, smoothing  ...             No
# 3                        Conditioning, non-comedogenic  ...             No
# 4                                       Non-irritating  ...             No
# ..                                                 ...  ...            ...
# 376        Controls oil, helps to maintain skin health  ...             No
# 377        Improves skin barrier function, moisturizes  ...          Avoid
# 378  Promotes collagen production, heals and repair...  ...             No
# 379    Restores skin barrier, antimicrobial properties  ...             No
# 380  Gradually releases Vitamin C, brightens and ev...  ...             No
#
#     Suitable for Children (0-3 years) Suitable for Youth (3-16 years)  \
# 0                                 Yes                             Yes
# 1                                 Yes                             Yes
# 2                                 Yes                             Yes
# 3                                 Yes                             Yes
# 4                                 Yes                             Yes
# ..                                ...                             ...
# 376                               Yes                             Yes
# 377                               Yes                             Yes
# 378                               Yes                             Yes
# 379                               Yes                             Yes
# 380                               Yes                             Yes
#
#     Chirality Esther Group Alcohol Group Benzyl Group Silicate Groups  \
# 0          No           No            No           No              No
# 1         Yes           No           Yes           No              No
# 2          No           No            No           No             Yes
# 3          No           No            No           No              No
# 4          No           No            No           No              No
# ..        ...          ...           ...          ...             ...
# 376        No           No            No           No              No
# 377        No          Yes           Yes           No              No
# 378        No           No            No           No              No
# 379        No           No           Yes           No              No
# 380        No          Yes           Yes           No              No
#
#     Alkyl Parahydroxybenzoate Group Availability Type
# 0                                No  Over-the-counter
# 1                                No  Over-the-counter
# 2                                No  Over-the-counter
# 3                                No  Over-the-counter
# 4                                No  Over-the-counter
# ..                              ...               ...
# 376                              No  Over-the-counter
# 377                              No  Over-the-counter
# 378                              No  Over-the-counter
# 379                              No  Over-the-counter
# 380                              No  Over-the-counter
#
# [381 rows x 22 columns]

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from IPython.display import display

# %%
import sys
sys.path.append('../')  # Ajoute le dossier parent à sys.path

# %%
from functions.visualizing import highlight_atoms

from functions.visualizing import visualize_molecules_for_cream
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from functions.visualizing import highlight_atoms
#       3 from functions.visualizing import visualize_molecules_for_cream
#
# ImportError: cannot import name 'highlight_atoms' from 'functions.visualizing' (/Users/victoire/Project/src/Proj_VCB/scripts/../functions/visualizing.py)

# %%
visualize_molecules_for_cream(database,"Nuxe")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 visualize_molecules_for_cream(database,"Nuxe")
#
# File ~/Project/src/Proj_VCB/scripts/../functions/visualizing.py:6, in visualize_molecules_for_cream(database, cream_name)
#       5 def visualize_molecules_for_cream(database, cream_name):
# ----> 6     df = pd.read_csv(database, sep=';')
#       7     filtered_df = df[df['Cream'] == cream_name]
#       8     color_map = {
#       9         'Isopropyl': (0, 1, 0),  # Vert
#      10         'NaOH': (0, 0, 1),       # Bleu
#    (...)
#      15         'Benzyl Salicylate': (1, 0.9, 0) # Orange 5
#      16     }
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/io/common.py:709, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     706 errors = errors or "strict"
#     708 # read_csv does not know whether the buffer is opened in binary/text mode
# --> 709 if _is_binary_mode(path_or_buf, mode) and "b" not in mode:
#     710     mode += "b"
#     712 # validate encoding and errors
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/io/common.py:1171, in _is_binary_mode(handle, mode)
#    1168 if issubclass(type(handle), text_classes):
#    1169     return False
# -> 1171 return isinstance(handle, _get_binary_io_classes()) or "b" in getattr(
#    1172     handle, "mode", mode
#    1173 )
#
# TypeError: argument of type 'method' is not iterable
